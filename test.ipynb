# %%
import pandas as pd

# %%
df = pd.read_csv('UK-Sanctions-List.csv', skiprows=1)

filt = df[df['OFSI Group ID'] == 10659]
filt
# Out:
# /var/folders/bb/sw9nz8bs6kb65llwfx5c1xnc0000gn/T/ipykernel_93358/2239038297.py:1: DtypeWarning: Columns (48,49,50,51,52,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('UK-Sanctions-List.csv', skiprows=1)
#       Last Updated Unique ID  OFSI Group ID UN Reference Number  \
# 27548   09/04/2025   INU0075        10659.0                 NaN
# 27549   09/04/2025   INU0075        10659.0                 NaN
# 27550   09/04/2025   INU0075        10659.0                 NaN
# 27551   09/04/2025   INU0075        10659.0                 NaN
# 27552   09/04/2025   INU0075        10659.0                 NaN
# ...            ...       ...            ...                 ...
# 31323   09/04/2025   INU0075        10659.0                 NaN
# 31324   09/04/2025   INU0075        10659.0                 NaN
# 31325   09/04/2025   INU0075        10659.0                 NaN
# 31326   09/04/2025   INU0075        10659.0                 NaN
# ...

# %%
df['Unique ID'].nunique()
# Out:
# 6046
